# %%
import pandas as pd
import numpy as np
import missingno as msno

# %%
## https://open.quiltdata.com/

# !quilt install ResidentMario/missingno_data
from quilt.data.ResidentMario import missingno_data

# %%
# %matplotlib inline

# %% [markdown]
# Aula baseada em: https://minerandodados.com.br/data-cleaning-com-python-2/
#
# ## Análise de Dados Faltantes

# %%
df = missingno_data.nyc_collision_factors()

# %%
df
# Out:
#       Unnamed: 0        DATE      TIME    BOROUGH  ZIP CODE   LATITUDE  \
# 0              0  11/10/2016  16:11:00   BROOKLYN   11208.0  40.662514
# 1              1  11/10/2016  05:11:00  MANHATTAN   10013.0  40.721323
# 2              2  04/16/2016  09:15:00   BROOKLYN   11201.0  40.687999
# 3              3  04/15/2016  10:20:00     QUEENS   11375.0  40.719228
# 4              4  04/15/2016  10:35:00   BROOKLYN   11210.0  40.632147
# ...          ...         ...       ...        ...       ...        ...
# 7298        7298  01/07/2016  21:30:00   BROOKLYN   11235.0  40.584305
# 7299        7299  01/06/2016  12:50:00   BROOKLYN   11220.0  40.638583
# 7300        7300  01/04/2016  17:45:00   BROOKLYN   11235.0  40.581744
# 7301        7301  01/02/2016  17:20:00  MANHATTAN   10016.0  40.750960
# 7302        7302  01/02/2016  20:00:00   BROOKLYN   11213.0  40.663604
#
#       LONGITUDE                   LOCATION      ON STREET NAME  \
# 0    -73.872007  (40.6625139, -73.8720068)      WORTMAN AVENUE
# 1    -74.008344  (40.7213228, -74.0083444)       HUBERT STREET
# 2    -73.997563  (40.6879989, -73.9975625)        HENRY STREET
# 3    -73.854542  (40.7192276, -73.8545422)                 nan
# 4    -73.952731  (40.6321467, -73.9527315)      BEDFORD AVENUE
# ...         ...                        ...                 ...
# 7298 -73.959113  (40.5843046, -73.9591125)      EAST 11 STREET
# 7299 -74.020772  (40.6385828, -74.0207721)            4 AVENUE
# 7300 -73.953836  (40.5817444, -73.9538363)     SHORE BOULEVARD
# 7301 -73.982723  (40.7509597, -73.9827227)      WEST 38 STREET
# 7302 -73.934391  (40.6636039, -73.9343912)  SCHENECTADY AVENUE
#
#      CROSS STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 1  \
# 0       MONTAUK AVENUE  ...  Failure to Yield Right-of-Way
# 1        HUDSON STREET  ...  Failure to Yield Right-of-Way
# 2        WARREN STREET  ...             Lost Consciousness
# 3                  nan  ...  Failure to Yield Right-of-Way
# 4          CAMPUS ROAD  ...  Failure to Yield Right-of-Way
# ...                ...  ...                            ...
# 7298       BLAKE COURT  ...             Lost Consciousness
# 7299         64 STREET  ...  Failure to Yield Right-of-Way
# 7300        CASS PLACE  ...  Failure to Yield Right-of-Way
# 7301          5 AVENUE  ...             Lost Consciousness
# 7302  EMPIRE BOULEVARD  ...             Lost Consciousness
#
#       CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                       Unspecified                            nan
# 1                               nan                            nan
# 2                Lost Consciousness                            nan
# 3     Failure to Yield Right-of-Way  Failure to Yield Right-of-Way
# 4     Failure to Yield Right-of-Way                            nan
# ...                             ...                            ...
# 7298                    Unspecified                            nan
# 7299                    Unspecified                            nan
# 7300                    Unspecified                            nan
# 7301             Lost Consciousness                            nan
# 7302                    Unspecified                            nan
#
#       CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 0                               nan                            nan
# 1                               nan                            nan
# 2                               nan                            nan
# 3                               nan                            nan
# 4                               nan                            nan
# ...                             ...                            ...
# 7298                            nan                            nan
# 7299                            nan                            nan
# 7300                            nan                            nan
# 7301                            nan                            nan
# 7302                            nan                            nan
#
#                 VEHICLE TYPE CODE 1            VEHICLE TYPE CODE 2  \
# 0                              TAXI              PASSENGER VEHICLE
# 1                 PASSENGER VEHICLE                            nan
# 2                 PASSENGER VEHICLE                            VAN
# 3                 PASSENGER VEHICLE              PASSENGER VEHICLE
# 4                 PASSENGER VEHICLE              PASSENGER VEHICLE
# ...                             ...                            ...
# 7298  SPORT UTILITY / STATION WAGON  SPORT UTILITY / STATION WAGON
# 7299              PASSENGER VEHICLE  SPORT UTILITY / STATION WAGON
# 7300              PASSENGER VEHICLE              PASSENGER VEHICLE
# 7301              PASSENGER VEHICLE                           TAXI
# 7302  SPORT UTILITY / STATION WAGON              PASSENGER VEHICLE
#
#      VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                    nan                 nan                 nan
# 1                    nan                 nan                 nan
# 2                    nan                 nan                 nan
# 3      PASSENGER VEHICLE                 nan                 nan
# 4                    nan                 nan                 nan
# ...                  ...                 ...                 ...
# 7298                 nan                 nan                 nan
# 7299                 nan                 nan                 nan
# 7300                 nan                 nan                 nan
# 7301                 nan                 nan                 nan
# 7302                 nan                 nan                 nan
#
# [7303 rows x 27 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0      ZIP CODE     LATITUDE    LONGITUDE  \
# count  7303.000000   6919.000000  7303.000000  7303.000000
# mean   3651.000000  10900.746640    40.717653   -73.921406
# std    2108.338841    551.568724     0.069437     0.083317
# min       0.000000  10001.000000    40.502341   -74.248277
# 25%    1825.500000  10310.000000    40.670865   -73.980744
# 50%    3651.000000  11211.000000    40.723260   -73.933888
# 75%    5476.500000  11355.000000    40.759527   -73.864463
# max    7302.000000  11694.000000    40.909628   -73.702590
#
#        NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# count                7303.000000               7303.000000
# mean                    0.350678                  0.000959
# std                     0.707873                  0.030947
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     0.000000                  0.000000
# 75%                     1.000000                  0.000000
# max                    16.000000                  1.000000
#
#        NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# count                    7303.000000                   7303.000000
# mean                        0.133644                      0.000822
# std                         0.362129                      0.028653
# min                         0.000000                      0.000000
# 25%                         0.000000                      0.000000
# 50%                         0.000000                      0.000000
# 75%                         0.000000                      0.000000
# max                         3.000000                      1.000000
#
#        NUMBER OF CYCLISTS INJURED  NUMBER OF CYCLISTS KILLED
# count                         0.0                        0.0
# mean                          NaN                        NaN
# std                           NaN                        NaN
# min                           NaN                        NaN
# 25%                           NaN                        NaN
# 50%                           NaN                        NaN
# 75%                           NaN                        NaN
# max                           NaN                        NaN

# %%
df.head(2).T
# Out:
#                                                            0  \
# Unnamed: 0                                                 0
# DATE                                              11/10/2016
# TIME                                                16:11:00
# BOROUGH                                             BROOKLYN
# ZIP CODE                                             11208.0
# LATITUDE                                           40.662514
# LONGITUDE                                         -73.872007
# LOCATION                           (40.6625139, -73.8720068)
# ON STREET NAME                                WORTMAN AVENUE
# CROSS STREET NAME                             MONTAUK AVENUE
# OFF STREET NAME                                          nan
# NUMBER OF PERSONS INJURED                                  0
# NUMBER OF PERSONS KILLED                                   0
# NUMBER OF PEDESTRIANS INJURED                              0
# NUMBER OF PEDESTRIANS KILLED                               0
# NUMBER OF CYCLISTS INJURED                               NaN
# NUMBER OF CYCLISTS KILLED                                NaN
# CONTRIBUTING FACTOR VEHICLE 1  Failure to Yield Right-of-Way
# CONTRIBUTING FACTOR VEHICLE 2                    Unspecified
# CONTRIBUTING FACTOR VEHICLE 3                            nan
# CONTRIBUTING FACTOR VEHICLE 4                            nan
# CONTRIBUTING FACTOR VEHICLE 5                            nan
# VEHICLE TYPE CODE 1                                     TAXI
# VEHICLE TYPE CODE 2                        PASSENGER VEHICLE
# VEHICLE TYPE CODE 3                                      nan
# VEHICLE TYPE CODE 4                                      nan
# VEHICLE TYPE CODE 5                                      nan
#
#                                                            1
# Unnamed: 0                                                 1
# DATE                                              11/10/2016
# TIME                                                05:11:00
# BOROUGH                                            MANHATTAN
# ZIP CODE                                             10013.0
# LATITUDE                                           40.721323
# LONGITUDE                                         -74.008344
# LOCATION                           (40.7213228, -74.0083444)
# ON STREET NAME                                 HUBERT STREET
# CROSS STREET NAME                              HUDSON STREET
# OFF STREET NAME                                          nan
# NUMBER OF PERSONS INJURED                                  1
# NUMBER OF PERSONS KILLED                                   0
# NUMBER OF PEDESTRIANS INJURED                              1
# NUMBER OF PEDESTRIANS KILLED                               0
# NUMBER OF CYCLISTS INJURED                               NaN
# NUMBER OF CYCLISTS KILLED                                NaN
# CONTRIBUTING FACTOR VEHICLE 1  Failure to Yield Right-of-Way
# CONTRIBUTING FACTOR VEHICLE 2                            nan
# CONTRIBUTING FACTOR VEHICLE 3                            nan
# CONTRIBUTING FACTOR VEHICLE 4                            nan
# CONTRIBUTING FACTOR VEHICLE 5                            nan
# VEHICLE TYPE CODE 1                        PASSENGER VEHICLE
# VEHICLE TYPE CODE 2                                      nan
# VEHICLE TYPE CODE 3                                      nan
# VEHICLE TYPE CODE 4                                      nan
# VEHICLE TYPE CODE 5                                      nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7303 entries, 0 to 7302
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     7303 non-null   int64
#  1   DATE                           7303 non-null   object
#  2   TIME                           7303 non-null   object
#  3   BOROUGH                        7303 non-null   object
#  4   ZIP CODE                       6919 non-null   float64
#  5   LATITUDE                       7303 non-null   float64
#  6   LONGITUDE                      7303 non-null   float64
#  7   LOCATION                       7303 non-null   object
#  8   ON STREET NAME                 7303 non-null   object
#  9   CROSS STREET NAME              7303 non-null   object
#  10  OFF STREET NAME                7303 non-null   object
#  11  NUMBER OF PERSONS INJURED      7303 non-null   int64
#  12  NUMBER OF PERSONS KILLED       7303 non-null   int64
#  13  NUMBER OF PEDESTRIANS INJURED  7303 non-null   int64
#  14  NUMBER OF PEDESTRIANS KILLED   7303 non-null   int64
#  15  NUMBER OF CYCLISTS INJURED     0 non-null      float64
#  16  NUMBER OF CYCLISTS KILLED      0 non-null      float64
#  17  CONTRIBUTING FACTOR VEHICLE 1  7303 non-null   object
#  18  CONTRIBUTING FACTOR VEHICLE 2  7303 non-null   object
#  19  CONTRIBUTING FACTOR VEHICLE 3  7303 non-null   object
#  20  CONTRIBUTING FACTOR VEHICLE 4  7303 non-null   object
#  21  CONTRIBUTING FACTOR VEHICLE 5  7303 non-null   object
#  22  VEHICLE TYPE CODE 1            7303 non-null   object
#  23  VEHICLE TYPE CODE 2            7303 non-null   object
#  24  VEHICLE TYPE CODE 3            7303 non-null   object
#  25  VEHICLE TYPE CODE 4            7303 non-null   object
#  26  VEHICLE TYPE CODE 5            7303 non-null   object
# dtypes: float64(5), int64(5), object(17)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                          0
# DATE                                0
# TIME                                0
# BOROUGH                             0
# ZIP CODE                          384
# LATITUDE                            0
# LONGITUDE                           0
# LOCATION                            0
# ON STREET NAME                      0
# CROSS STREET NAME                   0
# OFF STREET NAME                     0
# NUMBER OF PERSONS INJURED           0
# NUMBER OF PERSONS KILLED            0
# NUMBER OF PEDESTRIANS INJURED       0
# NUMBER OF PEDESTRIANS KILLED        0
# NUMBER OF CYCLISTS INJURED       7303
# NUMBER OF CYCLISTS KILLED        7303
# CONTRIBUTING FACTOR VEHICLE 1       0
# CONTRIBUTING FACTOR VEHICLE 2       0
# CONTRIBUTING FACTOR VEHICLE 3       0
# CONTRIBUTING FACTOR VEHICLE 4       0
# CONTRIBUTING FACTOR VEHICLE 5       0
# VEHICLE TYPE CODE 1                 0
# VEHICLE TYPE CODE 2                 0
# VEHICLE TYPE CODE 3                 0
# VEHICLE TYPE CODE 4                 0
# VEHICLE TYPE CODE 5                 0
# dtype: int64

# %%
df.replace('nan', np.NaN, inplace=True)

# %%
df.head(2).T
# Out:
#                                                            0  \
# Unnamed: 0                                                 0
# DATE                                              11/10/2016
# TIME                                                16:11:00
# BOROUGH                                             BROOKLYN
# ZIP CODE                                             11208.0
# LATITUDE                                           40.662514
# LONGITUDE                                         -73.872007
# LOCATION                           (40.6625139, -73.8720068)
# ON STREET NAME                                WORTMAN AVENUE
# CROSS STREET NAME                             MONTAUK AVENUE
# OFF STREET NAME                                          NaN
# NUMBER OF PERSONS INJURED                                  0
# NUMBER OF PERSONS KILLED                                   0
# NUMBER OF PEDESTRIANS INJURED                              0
# NUMBER OF PEDESTRIANS KILLED                               0
# NUMBER OF CYCLISTS INJURED                               NaN
# NUMBER OF CYCLISTS KILLED                                NaN
# CONTRIBUTING FACTOR VEHICLE 1  Failure to Yield Right-of-Way
# CONTRIBUTING FACTOR VEHICLE 2                    Unspecified
# CONTRIBUTING FACTOR VEHICLE 3                            NaN
# CONTRIBUTING FACTOR VEHICLE 4                            NaN
# CONTRIBUTING FACTOR VEHICLE 5                            NaN
# VEHICLE TYPE CODE 1                                     TAXI
# VEHICLE TYPE CODE 2                        PASSENGER VEHICLE
# VEHICLE TYPE CODE 3                                      NaN
# VEHICLE TYPE CODE 4                                      NaN
# VEHICLE TYPE CODE 5                                      NaN
#
#                                                            1
# Unnamed: 0                                                 1
# DATE                                              11/10/2016
# TIME                                                05:11:00
# BOROUGH                                            MANHATTAN
# ZIP CODE                                             10013.0
# LATITUDE                                           40.721323
# LONGITUDE                                         -74.008344
# LOCATION                           (40.7213228, -74.0083444)
# ON STREET NAME                                 HUBERT STREET
# CROSS STREET NAME                              HUDSON STREET
# OFF STREET NAME                                          NaN
# NUMBER OF PERSONS INJURED                                  1
# NUMBER OF PERSONS KILLED                                   0
# NUMBER OF PEDESTRIANS INJURED                              1
# NUMBER OF PEDESTRIANS KILLED                               0
# NUMBER OF CYCLISTS INJURED                               NaN
# NUMBER OF CYCLISTS KILLED                                NaN
# CONTRIBUTING FACTOR VEHICLE 1  Failure to Yield Right-of-Way
# CONTRIBUTING FACTOR VEHICLE 2                            NaN
# CONTRIBUTING FACTOR VEHICLE 3                            NaN
# CONTRIBUTING FACTOR VEHICLE 4                            NaN
# CONTRIBUTING FACTOR VEHICLE 5                            NaN
# VEHICLE TYPE CODE 1                        PASSENGER VEHICLE
# VEHICLE TYPE CODE 2                                      NaN
# VEHICLE TYPE CODE 3                                      NaN
# VEHICLE TYPE CODE 4                                      NaN
# VEHICLE TYPE CODE 5                                      NaN

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                          0
# DATE                                0
# TIME                                0
# BOROUGH                           383
# ZIP CODE                          384
# LATITUDE                            0
# LONGITUDE                           0
# LOCATION                            0
# ON STREET NAME                   1065
# CROSS STREET NAME                1137
# OFF STREET NAME                  6542
# NUMBER OF PERSONS INJURED           0
# NUMBER OF PERSONS KILLED            0
# NUMBER OF PEDESTRIANS INJURED       0
# NUMBER OF PEDESTRIANS KILLED        0
# NUMBER OF CYCLISTS INJURED       7303
# NUMBER OF CYCLISTS KILLED        7303
# CONTRIBUTING FACTOR VEHICLE 1       0
# CONTRIBUTING FACTOR VEHICLE 2    1085
# CONTRIBUTING FACTOR VEHICLE 3    7000
# CONTRIBUTING FACTOR VEHICLE 4    7244
# CONTRIBUTING FACTOR VEHICLE 5    7289
# VEHICLE TYPE CODE 1                58
# VEHICLE TYPE CODE 2              1520
# VEHICLE TYPE CODE 3              7019
# VEHICLE TYPE CODE 4              7249
# VEHICLE TYPE CODE 5              7291
# dtype: int64

# %% [markdown]
# ### Gráficos de Dados Preenchidos

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df.sample(250))
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (7303, 27)

# %%
df.dropna(thresh=int(df.shape[0] * .9), axis=1, inplace=True)

# %%
msno.matrix(df.sample(250))
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (7303, 14)

# %%
df.dropna(subset=['ZIP CODE'], inplace=True)

# %%
msno.matrix(df.sample(250))
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (6919, 14)

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#         Unnamed: 0      ZIP CODE     LATITUDE    LONGITUDE  \
# count  6919.000000   6919.000000  6919.000000  6919.000000
# mean   3643.004047  10900.746640    40.716509   -73.922947
# std    2110.802263    551.568724     0.069538     0.082569
# min       0.000000  10001.000000    40.502341   -74.248277
# 25%    1809.000000  10310.000000    40.669591   -73.981436
# 50%    3646.000000  11211.000000    40.722410   -73.935606
# 75%    5476.500000  11355.000000    40.759078   -73.868823
# max    7302.000000  11694.000000    40.909628   -73.702590
#
#        NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# count                6919.000000               6919.000000
# mean                    0.359445                  0.001012
# std                     0.708338                  0.031794
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     0.000000                  0.000000
# 75%                     1.000000                  0.000000
# max                    16.000000                  1.000000
#
#        NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED
# count                    6919.000000                   6919.000000
# mean                        0.140627                      0.000867
# std                         0.370214                      0.029437
# min                         0.000000                      0.000000
# 25%                         0.000000                      0.000000
# 50%                         0.000000                      0.000000
# 75%                         0.000000                      0.000000
# max                         3.000000                      1.000000

# %%
df2 = pd.read_csv(
    filepath_or_buffer='dataset/bcb/selic3.csv',
    sep=";")
df2
# Out:
#            data valor
# 0    01/06/1986  1,27
# 1    01/07/1986  1,95
# 2    01/08/1986  2,57
# 3    01/09/1986  2,94
# 4    01/10/1986  1,96
# ..          ...   ...
# 411  01/09/2020  0,16
# 412  01/10/2020  0,16
# 413  01/11/2020    na
# 414  01/12/2020  0,16
# 415  01/01/2021  0,13
#
# [416 rows x 2 columns]

# %%
df2.isnull().sum()
# Out:
# data     0
# valor    0
# dtype: int64

# %%
# 278, 384
missing_values = ['n/a','na','--','.', 'nan']
df2 = pd.read_csv(
    filepath_or_buffer='dataset/bcb/selic3.csv',
    sep=";",
    na_values=missing_values)
df2
# Out:
#            data valor
# 0    01/06/1986  1,27
# 1    01/07/1986  1,95
# 2    01/08/1986  2,57
# 3    01/09/1986  2,94
# 4    01/10/1986  1,96
# ..          ...   ...
# 411  01/09/2020  0,16
# 412  01/10/2020  0,16
# 413  01/11/2020   NaN
# 414  01/12/2020  0,16
# 415  01/01/2021  0,13
#
# [416 rows x 2 columns]

# %%
df2['valor'] = pd.to_numeric(df2.valor.str.replace(',', '.'))

# %%
df2.isnull().sum()
# Out:
# data     0
# valor    5
# dtype: int64

# %%
msno.matrix(df2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html

# %%
df2[df2.index.isin([276, 277, 278])] # 382, 383, 384,
# Out:
#            data  valor
# 276  01/06/2009   0.76
# 277  01/07/2009    NaN
# 278  01/08/2009   0.69

# %%
df2.fillna(0)[df2.index==277]
# Out:
#            data  valor
# 277  01/07/2009    0.0

# %%
df2.fillna(method='bfill')[df2.index==277]
# Out:
#            data  valor
# 277  01/07/2009   0.69

# %%
df2.fillna(method='ffill')[df2.index==277]
# Out:
#            data  valor
# 277  01/07/2009   0.76

# %% [markdown]
# df

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.interpolate.html#pandas.DataFrame.interpolate

# %%
df2.interpolate(method='linear')[df2.index==277]
# Out:
#            data  valor
# 277  01/07/2009  0.725

# %%
msno.matrix(df2.interpolate(method='linear'))
# Out:
# <AxesSubplot:>
