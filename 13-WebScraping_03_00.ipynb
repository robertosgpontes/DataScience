# %% [markdown]
# https://www.youtube.com/watch?v=Vxl5jUltHBo
#
#
# https://github.com/gabrielfroes/webscraping_python_selenium
#
#
# https://selenium-python.readthedocs.io/locating-elements.html

# %%
import pandas as pd
import numpy as np

# %%
import re

# %%
import requests
from bs4 import BeautifulSoup, Comment
from selenium import webdriver
from selenium.webdriver.firefox.options import Options

# %%
url = 'https://www.nba.com/stats/players/traditional/'

# %%
option = Options()
option.headless = True
driver = webdriver.Firefox(options=option)

# %%
driver.get(url)
driver.implicitly_wait(5)

# %%
driver.find_element_by_id('onetrust-accept-btn-handler').click()
driver.implicitly_wait(5)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-10-5ac50b3cbc63> in <module>
# ----> 1 driver.find_element_by_id('onetrust-accept-btn-handler').click()
#       2 driver.implicitly_wait(5)
#
# ~/.venvs/datascience/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/.venvs/datascience/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.venvs/datascience/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.venvs/datascience/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: Element <button id="onetrust-accept-btn-handler"> could not be scrolled into view

# %%
driver.find_element_by_xpath(
        f"//div[@class='nba-stat-table']//table//thead//tr//th[@data-field='AGE']").click()

# %%
driver.implicitly_wait(5)

# %%
element = driver.find_element_by_xpath(
        "//div[@class='nba-stat-table']//table")

# %%
html_content = element.get_attribute('outerHTML')

# %%
soup = BeautifulSoup(html_content, 'html.parser')
table = soup.find(name='table')

# %%
df_full = pd.read_html(str(table))[0]

# %%
df_full
# Out:
#     Unnamed: 0             PLAYER TEAM  AGE  GP   W   L   MIN   PTS  FGM  ...  \
# 0          NaN     Andre Iguodala  MIA   37  45  25  20  21.3   4.6  1.6  ...
# 1          NaN    Carmelo Anthony  POR   36  47  28  19  25.9  13.7  4.9  ...
# 2          NaN          JJ Redick  DAL   36  31  14  17  18.6   8.7  2.8  ...
# 3          NaN       LeBron James  LAL   36  41  28  13  33.9  25.4  9.5  ...
# 4          NaN         Marc Gasol  LAL   36  40  27  13  19.7   4.8  1.6  ...
# 5          NaN       Paul Millsap  DEN   36  38  24  14  23.1   9.6  3.6  ...
# 6          NaN         Chris Paul  PHX   35  47  33  14  31.7  16.0  6.1  ...
# 7          NaN      Dwight Howard  PHI   35  48  33  15  17.3   7.0  2.6  ...
# 8          NaN       Jared Dudley  LAL   35  11   6   5   6.9   0.5  0.2  ...
# 9          NaN         Kyle Lowry  TOR   35  39  12  27  34.6  17.0  5.6  ...
# 10         NaN  LaMarcus Aldridge  BKN   35  22  13   9  26.1  13.6  5.4  ...
# 11         NaN        P.J. Tucker  MIL   35  35  14  21  28.6   4.1  1.4  ...
# 12         NaN        Rajon Rondo  LAC   35  27  16  11  14.9   3.9  1.6  ...
# 13         NaN         Taj Gibson  NYK   35  22  12  10  19.7   4.7  1.9  ...
# 14         NaN       Trevor Ariza  MIA   35   8   3   5  23.6   6.1  2.1  ...
# 15         NaN         Al Horford  OKC   34  28  11  17  27.9  14.2  5.8  ...
# 16         NaN        Aron Baynes  TOR   34  46  18  28  18.5   5.7  2.4  ...
# 17         NaN     Garrett Temple  CHI   34  37  16  21  27.1   8.1  3.0  ...
# 18         NaN        George Hill  PHI   34  14   6   8  26.3  11.8  4.4  ...
# 19         NaN       Goran Dragic  MIA   34  30  17  13  26.8  13.5  4.9  ...
# 20         NaN      James Johnson  NOP   34  31  13  18  18.1   6.4  2.5  ...
# 21         NaN         Jeff Green  BKN   34  45  30  15  26.7   9.8  3.5  ...
# 22         NaN       Lou Williams  ATL   34  44  28  16  22.1  12.2  4.4  ...
# 23         NaN           Rudy Gay  SAS   34  39  21  18  21.8  11.1  4.1  ...
# 24         NaN    Wesley Matthews  LAL   34  42  24  18  19.9   4.5  1.5  ...
# 25         NaN        Brook Lopez  MIL   33  48  31  17  27.1  11.1  4.1  ...
# 26         NaN      D.J. Augustin  HOU   33  45  26  19  19.4   6.8  2.1  ...
# 27         NaN        Danny Green  PHI   33  48  33  15  28.5   9.7  3.4  ...
# 28         NaN     Ersan Ilyasova  UTA   33   4   4   0   4.3   0.5  0.3  ...
# 29         NaN       JaVale McGee  DEN   33  33  13  20  15.2   8.0  3.4  ...
# 30         NaN         Joe Ingles  UTA   33  44  33  11  26.6  11.9  4.0  ...
# 31         NaN        Mike Conley  UTA   33  39  29  10  29.7  16.3  5.7  ...
# 32         NaN        Robin Lopez  WAS   33  47  17  30  20.2   8.4  3.4  ...
# 33         NaN      Stephen Curry  GSW   33  41  22  19  33.7  29.2  9.6  ...
# 34         NaN    Wayne Ellington  DET   33  35  10  25  23.1  10.6  3.6  ...
# 35         NaN      Blake Griffin  BKN   32  25  11  14  28.8  11.5  3.8  ...
# 36         NaN   Boban Marjanovic  DAL   32  22   8  14   8.4   4.6  2.0  ...
# 37         NaN   Danilo Gallinari  ATL   32  36  18  18  23.7  12.9  3.9  ...
# 38         NaN     DeAndre Jordan  BKN   32  46  31  15  22.2   7.5  3.4  ...
# 39         NaN       Derrick Rose  NYK   32  28  12  16  23.7  13.1  4.9  ...
# 40         NaN      E'Twaun Moore  PHX   32  24  18   6  14.5   4.3  1.8  ...
# 41         NaN        Eric Gordon  HOU   32  27  10  17  29.2  17.8  5.9  ...
# 42         NaN          Ish Smith  WAS   32  19   6  13  20.6   5.2  2.3  ...
# 43         NaN        Jeff Teague  MIL   32  35  16  19  18.0   6.7  2.3  ...
# 44         NaN       Kevin Durant  BKN   32  19  12   7  35.8  29.0  9.9  ...
# 45         NaN         Kevin Love  CLE   32   5   2   3  15.6   7.2  2.2  ...
# 46         NaN         Mike Scott  PHI   32  29  21   8  17.8   4.0  1.4  ...
# 47         NaN    Nemanja Bjelica  MIA   32  29  13  16  16.1   6.7  2.5  ...
# 48         NaN      Nicolas Batum  LAC   32  47  30  17  28.8   8.4  2.9  ...
# 49         NaN   Patrick Beverley  LAC   32  29  19  10  23.8   8.3  2.8  ...
#
#     REB RANK  AST RANK  TOV RANK  STL RANK  BLK RANK  PF RANK  FP RANK  \
# 0        NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 1        NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 2        NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 3        NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 4        NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 5        NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 6        NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 7        NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 8        NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 9        NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 10       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 11       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 12       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 13       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 14       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 15       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 16       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 17       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 18       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 19       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 20       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 21       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 22       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 23       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 24       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 25       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 26       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 27       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 28       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 29       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 30       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 31       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 32       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 33       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 34       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 35       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 36       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 37       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 38       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 39       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 40       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 41       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 42       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 43       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 44       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 45       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 46       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 47       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 48       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 49       NaN       NaN       NaN       NaN       NaN      NaN      NaN
#
#     DD2 RANK  TD3 RANK  +/- RANK
# 0        NaN       NaN       NaN
# 1        NaN       NaN       NaN
# 2        NaN       NaN       NaN
# 3        NaN       NaN       NaN
# 4        NaN       NaN       NaN
# 5        NaN       NaN       NaN
# 6        NaN       NaN       NaN
# 7        NaN       NaN       NaN
# 8        NaN       NaN       NaN
# 9        NaN       NaN       NaN
# 10       NaN       NaN       NaN
# 11       NaN       NaN       NaN
# 12       NaN       NaN       NaN
# 13       NaN       NaN       NaN
# 14       NaN       NaN       NaN
# 15       NaN       NaN       NaN
# 16       NaN       NaN       NaN
# 17       NaN       NaN       NaN
# 18       NaN       NaN       NaN
# 19       NaN       NaN       NaN
# 20       NaN       NaN       NaN
# 21       NaN       NaN       NaN
# 22       NaN       NaN       NaN
# 23       NaN       NaN       NaN
# 24       NaN       NaN       NaN
# 25       NaN       NaN       NaN
# 26       NaN       NaN       NaN
# 27       NaN       NaN       NaN
# 28       NaN       NaN       NaN
# 29       NaN       NaN       NaN
# 30       NaN       NaN       NaN
# 31       NaN       NaN       NaN
# 32       NaN       NaN       NaN
# 33       NaN       NaN       NaN
# 34       NaN       NaN       NaN
# 35       NaN       NaN       NaN
# 36       NaN       NaN       NaN
# 37       NaN       NaN       NaN
# 38       NaN       NaN       NaN
# 39       NaN       NaN       NaN
# 40       NaN       NaN       NaN
# 41       NaN       NaN       NaN
# 42       NaN       NaN       NaN
# 43       NaN       NaN       NaN
# 44       NaN       NaN       NaN
# 45       NaN       NaN       NaN
# 46       NaN       NaN       NaN
# 47       NaN       NaN       NaN
# 48       NaN       NaN       NaN
# 49       NaN       NaN       NaN
#
# [50 rows x 56 columns]

# %%
driver.find_element_by_xpath(
        f"//div[@class='nba-stat-table']//table//thead//tr//th[@data-field='PTS']").click()

# %%
driver.implicitly_wait(5)

# %%
element = driver.find_element_by_xpath(
        "//div[@class='nba-stat-table']//table")
html_content = element.get_attribute('outerHTML')
soup = BeautifulSoup(html_content, 'html.parser')
table = soup.find(name='table')
df_full = pd.read_html(str(table))[0]

# %%
df_full
# Out:
#     Unnamed: 0                  PLAYER TEAM  AGE  GP   W   L   MIN  PTS  FGM  \
# 0          502        Anzejs Pasecniks  WAS   25   1   1   0   6.3  0.0  0.0
# 1          502           Ashton Hagans  MIN   21   2   0   2   2.0  0.0  0.0
# 2          502        Greg Whittington  DEN   28   4   3   1   3.0  0.0  0.0
# 3          502     Matthew Dellavedova  CLE   30   1   0   1  16.2  0.0  0.0
# 4          502             Noah Vonleh  BKN   25   4   3   1   2.7  0.0  0.0
# 5          502             Will Magnay  NOP   22   1   1   0   3.3  0.0  0.0
# 6          501          Wenyen Gabriel  NOP   24   7   4   3   4.4  0.1  0.0
# 7          499       Terrance Ferguson  PHI   22  13  10   3   3.8  0.2  0.1
# 8          499             Theo Pinson  NYK   25  13   6   7   2.2  0.2  0.1
# 9          498            Jaylen Adams  MIL   24   7   5   2   2.6  0.3  0.1
# 10         497          Keljin Blevins  POR   25  10   4   6   5.1  0.4  0.2
# 11         494          Ersan Ilyasova  UTA   33   4   4   0   4.3  0.5  0.3
# 12         494        Ignas Brazdeikis  PHI   22   4   2   2   1.8  0.5  0.0
# 13         494  Quinndary Weatherspoon  SAS   24  12   5   7   4.2  0.5  0.2
# 14         493            Jared Dudley  LAL   35  11   6   5   6.9  0.5  0.2
# 15         492        Vernon Carey Jr.  CHA   20   8   5   3   3.3  0.6  0.3
# 16         489        Cameron Reynolds  SAS   26   3   2   1   2.1  0.7  0.3
# 17         489            Jared Harper  NYK   23   3   2   1   2.4  0.7  0.0
# 18         489           Trent Forrest  UTA   22  12  10   2   4.3  0.7  0.3
# 19         488       Deividas Sirvydis  DET   20  10   5   5   1.9  0.7  0.2
# 20         486            Jalen Harris  TOR   22   4   2   2   3.5  0.8  0.3
# 21         486    Kostas Antetokounmpo  LAL   23   8   4   4   4.0  0.8  0.3
# 22         483            Axel Toupane  MIL   28   5   2   3   8.1  0.8  0.4
# 23         483       Ty-Shon Alexander  PHX   22   5   4   1   3.0  0.8  0.2
# 24         483         Vincent Poirier  PHI   27  10   8   2   3.9  0.8  0.3
# 25         482               Tyler Bey  DAL   23   9   5   4   3.5  0.9  0.3
# 26         481            Anthony Gill  WAS   28  13   3  10   5.5  0.9  0.3
# 27         480            Juwan Morgan  UTA   23  19  16   3   4.4  0.9  0.4
# 28         470          Brian Bowen II  IND   22   3   1   2   2.7  1.0  0.3
# 29         470         Cassius Stanley  IND   21  13   7   6   2.7  1.0  0.3
# 30         470           Iman Shumpert  BKN   30   2   1   1   5.5  1.0  0.5
# 31         470              Karim Mane  ORL   20   9   2   7   9.4  1.0  0.2
# 32         470            Nate Darling  CHA   22   3   2   1   3.1  1.0  0.3
# 33         470           Patrick McCaw  TOR   25   5   2   3   6.7  1.0  0.2
# 34         470          Rodions Kurucs  MIL   23  16   7   9   5.7  1.0  0.4
# 35         470      Shaquille Harrison  UTA   27  17  15   2   3.3  1.0  0.4
# 36         470            Tyrell Terry  DAL   20  11   2   9   5.1  1.0  0.5
# 37         470          Udoka Azubuike  UTA   21  12  11   1   4.1  1.0  0.3
# 38         469           Nick Richards  CHA   23  12   7   5   3.5  1.1  0.3
# 39         468           Markus Howard  DEN   22  22  13   9   3.4  1.1  0.4
# 40         467          Marques Bolden  CLE   22   6   2   4   4.8  1.2  0.2
# 41         466       Mfiondu Kabengele  LAC   23  23  18   5   4.1  1.2  0.4
# 42         464          Andre Roberson  BKN   29   5   4   1  12.6  1.2  0.4
# 43         464            Kelan Martin  IND   25  15   6   9   3.7  1.2  0.5
# 44         463     Sindarius Thornwell  NOP   26  14   7   7   5.2  1.2  0.5
# 45         462            Jalen Lecque  IND   20   4   2   2   3.0  1.3  0.3
# 46         461             Jalen Smith  PHX   21  16  12   4   4.6  1.3  0.6
# 47         458       Cristiano Felicio  CHI   28   9   1   8   4.8  1.3  0.3
# 48         458            Devon Dotson  CHI   21   3   0   3   4.9  1.3  0.7
# 49         458             Tim Frazier  MEM   30   3   3   0  10.8  1.3  0.7
#
#     ...  REB RANK  AST RANK  TOV RANK  STL RANK  BLK RANK  PF RANK  FP RANK  \
# 0   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 1   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 2   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 3   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 4   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 5   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 6   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 7   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 8   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 9   ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 10  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 11  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 12  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 13  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 14  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 15  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 16  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 17  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 18  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 19  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 20  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 21  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 22  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 23  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 24  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 25  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 26  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 27  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 28  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 29  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 30  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 31  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 32  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 33  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 34  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 35  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 36  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 37  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 38  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 39  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 40  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 41  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 42  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 43  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 44  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 45  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 46  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 47  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 48  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
# 49  ...       NaN       NaN       NaN       NaN       NaN      NaN      NaN
#
#     DD2 RANK  TD3 RANK  +/- RANK
# 0        NaN       NaN       NaN
# 1        NaN       NaN       NaN
# 2        NaN       NaN       NaN
# 3        NaN       NaN       NaN
# 4        NaN       NaN       NaN
# 5        NaN       NaN       NaN
# 6        NaN       NaN       NaN
# 7        NaN       NaN       NaN
# 8        NaN       NaN       NaN
# 9        NaN       NaN       NaN
# 10       NaN       NaN       NaN
# 11       NaN       NaN       NaN
# 12       NaN       NaN       NaN
# 13       NaN       NaN       NaN
# 14       NaN       NaN       NaN
# 15       NaN       NaN       NaN
# 16       NaN       NaN       NaN
# 17       NaN       NaN       NaN
# 18       NaN       NaN       NaN
# 19       NaN       NaN       NaN
# 20       NaN       NaN       NaN
# 21       NaN       NaN       NaN
# 22       NaN       NaN       NaN
# 23       NaN       NaN       NaN
# 24       NaN       NaN       NaN
# 25       NaN       NaN       NaN
# 26       NaN       NaN       NaN
# 27       NaN       NaN       NaN
# 28       NaN       NaN       NaN
# 29       NaN       NaN       NaN
# 30       NaN       NaN       NaN
# 31       NaN       NaN       NaN
# 32       NaN       NaN       NaN
# 33       NaN       NaN       NaN
# 34       NaN       NaN       NaN
# 35       NaN       NaN       NaN
# 36       NaN       NaN       NaN
# 37       NaN       NaN       NaN
# 38       NaN       NaN       NaN
# 39       NaN       NaN       NaN
# 40       NaN       NaN       NaN
# 41       NaN       NaN       NaN
# 42       NaN       NaN       NaN
# 43       NaN       NaN       NaN
# 44       NaN       NaN       NaN
# 45       NaN       NaN       NaN
# 46       NaN       NaN       NaN
# 47       NaN       NaN       NaN
# 48       NaN       NaN       NaN
# 49       NaN       NaN       NaN
#
# [50 rows x 56 columns]

# %%
driver.implicitly_wait(10)

# %%
driver.quit()

# %%
option = Options()
option.headless = True
driver = webdriver.Firefox(options=option)

# %%
url = 'https://dhui.cp2.g12.br/login'

# %%
driver.get(url)
driver.implicitly_wait(5)

# %%
driver.find_element_by_id('username').send_keys('usuario')
driver.find_element_by_id('password').send_keys('senha')
driver.find_element_by_id('_submit').click()

# %%
driver.implicitly_wait(10)

# %%
driver.quit()
